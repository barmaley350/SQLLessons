# %%
import sqlite3
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# %%
xlsx_path = Path(Path.cwd().parent) / "db/raw_data/test_data.xlsx"
xlsx_path
# Out:
# PosixPath('/home/jovyan/work/db/raw_data/test_data.xlsx')

# %%
df_2026 = pd.read_excel(xlsx_path, sheet_name=1)
df_2025 = pd.read_excel(xlsx_path, sheet_name=2)
df_total = pd.read_excel(xlsx_path, sheet_name=3)

# %%
df_2025.head()
# Out:
#   Учетный день  Номер чека      Время открытия  Час открытия  \
# 0   2025-02-01       12590 2025-02-01 10:06:50            10
# 1   2025-02-01       12590 2025-02-01 10:06:50            10
# 2   2025-02-01       12590 2025-02-01 10:06:50            10
# 3   2025-02-01       12591 2025-02-01 10:17:40            10
# 4   2025-02-01       12591 2025-02-01 10:17:40            10
#
#        Время закрытия  Час закрытия                                Блюдо  \
# 0 2025-02-01 10:19:04            10    Д.Сырники с клубничным вареньем +
# 1 2025-02-01 10:19:04            10          Д.Тёплый римский сэндвич  +
# 2 2025-02-01 10:19:04            10                      клубника (30 г)
# 3 2025-02-01 10:39:13            10  Д.Бенедикт с лососем на круассане +
# 4 2025-02-01 10:39:13            10         Д.Драник с лососем и яйцом +
#
#   Категория блюда      Тип заказа  Количество блюд  Количество гостей  \
# 0      Д.ЗАВТРАКИ  Яндекс.ультима              2.0                  2
# ...

# %%
df_2025.dtypes
# Out:
# Учетный день            datetime64[us]
# Номер чека                       int64
# Время открытия          datetime64[us]
# Час открытия                     int64
# Время закрытия          datetime64[us]
# Час закрытия                     int64
# Блюдо                              str
# Категория блюда                    str
# Тип заказа                         str
# Количество блюд                float64
# Количество гостей                int64
# Сумма со скидкой, р.           float64
# dtype: object

# %%
df_2026.head()
# Out:
#   Учетный день  Номер чека      Время открытия  Час открытия  \
# 0   2026-02-01       39551 2026-02-01 09:02:23             9
# 1   2026-02-01       39551 2026-02-01 09:02:23             9
# 2   2026-02-01       39551 2026-02-01 09:02:23             9
# 3   2026-02-01       39551 2026-02-01 09:02:23             9
# 4   2026-02-01       39551 2026-02-01 09:02:23             9
#
#            Время закрытия  Час закрытия                                 Блюдо  \
# 0 2026-02-01 10:02:53.685            10              Д.NEW Английский завтрак
# 1 2026-02-01 10:02:53.685            10  Д.Овсяная каша с бананом и голубикой
# 2 2026-02-01 10:02:53.685            10                        Д.Салат Табуле
# 3 2026-02-01 10:02:53.685            10             Д.Тёплый римский сэндвич
# 4 2026-02-01 10:02:53.685            10                               обычное
#
#   Категория блюда                      Тип заказа  Количество блюд  \
# ...

# %%
df_2026.dtypes
# Out:
# Учетный день            datetime64[us]
# Номер чека                       int64
# Время открытия          datetime64[us]
# Час открытия                     int64
# Время закрытия          datetime64[us]
# Час закрытия                     int64
# Блюдо                              str
# Категория блюда                    str
# Тип заказа                         str
# Количество блюд                float64
# Количество гостей                int64
# Сумма со скидкой, р.           float64
# dtype: object

# %%
df_total.head()
# Out:
#   Учетный день   План на день       Ресторан    БАНКЕТ НАШ    Банкет C&B  \
# 0   2026-02-01  945610.236397  621234.650671  71048.401550  33979.670306
# 1   2026-02-02  571575.604657  375506.268253  42945.318814  20539.065520
# 2   2026-02-03  705795.641717  463684.393475  53029.937954  25362.144239
# 3   2026-02-04  688107.641717  452063.962479  51700.950515  24726.541550
# 4   2026-02-05  924324.908967  607250.894530  69449.129004  33214.800828
#
#        Агрегатор     Самовывоз      Доставка
# 0  126349.480927  27899.409883  65098.623060
# 1   76372.143806  16863.842479  39348.965785
# 2   94306.205177  20823.888262  48589.072611
# 3   91942.789964  20302.019163  47371.378046
# 4  123505.402078  27271.404758  63633.277769

# %%
df_total.dtypes
# Out:
# Учетный день    datetime64[us]
# План на день           float64
# Ресторан               float64
# БАНКЕТ НАШ             float64
# Банкет C&B             float64
# Агрегатор              float64
# Самовывоз              float64
# Доставка               float64
# dtype: object
